# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
from matplotlib import pyplot as plt
import matplotlib.patches as patches
import seaborn as sns
# %matplotlib inline

# %%
#df = pd.read_excel (r'C:\Users\alberto\Desktop\work\CPM day-weekly-w-objective\CPM daily result exported\daily CPM 1-01to26-11.xlsx')

# %%
#CPM camparison with Reach as object
Day = df['Day']
index = np.arange(7)
bar_width = 0.38
plt.figure(dpi=220)

#Standard CPM list: daily_CPM_instant_article, daily_CPM_instagram_explore, daily_CPM_instagram_stories, daily_CPM_messenger_stories,
#daily_CPM_facebook_stories, daily_CPM_messenger_inbox, daily_CPM_marketplace, daily_CPM_feed
#daily_CPM_an_classic, daily_CPM_rewarded_video, daily_CPM_right_hand_column
fig, ax = plt.subplots()
Bar1 = ax.bar(index, df['daily_CPM_an_classic'], bar_width,
                label="Normal")
#CPM List wih Reach as object:#daily_CPM_instant_article_Reach, daily_CPM_instagram_explore_Reach, daily_CPM_instagram_stories_Reach, 
#daily_CPM_messenger_stories_Reach(NaN), daily_CPM_facebook_stories_Reach
#daily_CPM_an_classic_Reach, daily_CPM_rewarded_video_Reach, daily_CPM_right_hand_column_Reach
Bar2 = ax.bar(index+bar_width, df['daily_CPM_an_classic_Reach'],
                 bar_width, label="With the object")

ax.set_ylabel('CPM')
ax.set_xlabel('Day of the week')
ax.set_title('CPM')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(Day)
plt.xticks(rotation=90)
ax.legend()

#plt.show()

# %%
#CPM camparison with Conversions as object

Day = df['Day']
index = np.arange(7)
bar_width = 0.38
plt.figure(dpi=220)

#Standard CPM list: daily_CPM_instant_article, daily_CPM_instagram_explore, daily_CPM_instagram_stories, daily_CPM_messenger_stories,
#daily_CPM_facebook_stories, daily_CPM_messenger_inbox, daily_CPM_marketplace, daily_CPM_feed
#daily_CPM_an_classic, daily_CPM_rewarded_video, daily_CPM_right_hand_column
fig, ax = plt.subplots()
Bar1 = ax.bar(index, df['daily_CPM_feed'], bar_width,
                label="Normal")
#CPM List wih Conversions as object: daily_CPM_instant_article_Conversions, daily_CPM_instagram_explore_Conversions, 
#daily_CPM_instagram_stories_Conversions, daily_CPM_messenger_stories_Conversions,
#daily_CPM_facebook_stories_Conversions, daily_CPM_messenger_inbox_Conversions, 
#daily_CPM_marketplace_Conversions, daily_CPM_feed_Conversions
#daily_CPM_an_classic_Conversansions, daily_CPM_rewarded_video_Conversansions, daily_CPM_right_hand_column_Conversansions

Bar2 = ax.bar(index+bar_width, df['daily_CPM_feed_Conversions'],
                 bar_width, label="With the object")

ax.set_ylabel('CPM')
ax.set_xlabel('Day of the week')
ax.set_title('CPM')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(Day)
plt.xticks(rotation=90)
ax.legend()

#plt.show()

# %%
#CPM camparison with Traffic as object

Day = df['Day']
index = np.arange(7)
bar_width = 0.38
plt.figure(dpi=220)

#Standard CPM list: daily_CPM_instant_article, daily_CPM_instagram_explore, daily_CPM_instagram_stories, daily_CPM_messenger_stories,
#daily_CPM_facebook_stories, daily_CPM_messenger_inbox, daily_CPM_marketplace, daily_CPM_feed
#daily_CPM_an_classic, daily_CPM_rewarded_video, daily_CPM_right_hand_column
fig, ax = plt.subplots()
Bar1 = ax.bar(index, df['daily_CPM_marketplace'], bar_width,
                label="Normal")
#CPM List wih Traffic as object: daily_CPM_instant_article_Traffic, daily_CPM_instagram_explore_Traffic, 
#daily_CPM_instagram_stories_Traffic, daily_CPM_messenger_stories_Traffic,
#daily_CPM_facebook_stories_Traffic, daily_CPM_messenger_inbox_Traffic, 
#daily_CPM_marketplace_Traffic, daily_CPM_feed_Traffic
#daily_CPM_an_classic_Traffic, daily_CPM_rewarded_video_Traffic, daily_CPM_right_hand_column_Traffic

Bar2 = ax.bar(index+bar_width, df['daily_CPM_marketplace_Traffic'],
                 bar_width, label="With the object")

ax.set_ylabel('CPM')
ax.set_xlabel('Day of the week')
ax.set_title('CPM')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(Day)
plt.xticks(rotation=90)
ax.legend()

#plt.show()
